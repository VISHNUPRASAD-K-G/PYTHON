# %%
import matplotlib.pyplot as plt

x=[1,4,2,5,8,6]
plt.plot(x)
plt.grid()
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
plt.figure()

plt.stem(x)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
