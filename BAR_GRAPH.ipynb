# %%
import matplotlib.pyplot as plt

fig=plt.figure()
lang=['c','c++','java','python','php']
students=[10,20,35,20,12]
plt.bar(lang,students,color='orange')
plt.xlabel("Language")
plt.ylabel("No: Of Students")
plt.title('Programming Language')
plt.show()
